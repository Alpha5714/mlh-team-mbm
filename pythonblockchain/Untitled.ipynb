# %%
from hashlib import sha256
from tkinter import *
import time
import sys
import webbrowser
global LastHash;LastHash=""

try:
    open('HASH.dat','x').write('')
except:
    pass

#global difficulty
difficulty=1


#global index
index=[]

class block:
    
    def __init__(self,data):
        self.timestamp=self.timestampee()
        self.LastHash=LastHash
        self.data=data
        a=[]
        a=block.Hashe(data,LastHash,self.timestamp)
        self.Hash=str(a[0])
        self.epoch=str(a[1])
        block.addBlock(self.data,self.Hash,self.LastHash,self.timestamp,self.epoch)

    def reset_hash():
        global LastHash
        LastHash= str(open("HASH.dat",'r').read())
        
        
    def timestampee(self):
        a=int(float(time.time()*1000))
        a=str(a)
        return a

    def printblock(timestamp,LastHash,Hash,data,epoch):
        a=str("Block was added with \n Timestamp=%s \n lastHash= %s \n Hash=%s \n Data= %s \n epoch= %s \n \n \n"%
              (str(timestamp),str(LastHash),str(Hash)[0:15],str(data),str(epoch)))
        open('HASH.dat','w').write(str(Hash[0:15]))
        print(a)
        block.reset_hash()
        #return a

    def toHex(x):
        x=x.encode('utf-32')
        x=(sha256(x)).hexdigest()
        return x
        
    def Hashe(data,LastHash,timestamp):
        epoch=0
        #global Hash
        Hash=""
        temp=" "
        a=""
        while(temp[0:difficulty]!=a):
            timestamp=block.timestampee(3)
            temp=(''+str(data)+str(LastHash)+str(timestamp)+'')
            cond2=str(block.toHex(("0"*difficulty)))
            temp=str(block.toHex(temp))
            a= str(block.toHex("0"*difficulty))
            a=a[0:difficulty]
            epoch=epoch+1

        Hash=str(temp)
        
        return [Hash,epoch]

    def genesis():
        data='1st Block'
        Hash="f1r5t Ha5h"
        LastHash=""
        timestamp="Genesis Time"
        epoch=0
        block.addBlock(data,Hash,LastHash,timestamp,epoch)


    def addBlock(data,Hash,LastHash,timestamp,epoch):
        gene=block.printblock(timestamp,LastHash,Hash,data,epoch)
        index.append(gene)



def write_html(data):
    htmlstart=str(open("toread.html","r").read())
    #now writing in the web
    htmlend=str(open('toend.html','r').read())
    
    total=""
    open('temp_data.html','w').write(htmlstart)
    
    for i in range(0,20):
        if (i%2!=0 or i==0):
            total=str(""+str(index[i]))
            total=total.replace('\n','<br>')
            open('temp_data.html','a').write(total)
            total=""
    

    
    open('temp_data.html','a').write(htmlend)


def runhtml():
    webbrowser.open('temp_data.html')

index[0]=block.genesis()

for i in range(1,20):
    data=("THIS IS BLOCK NO. "+str(i))
    index.append(str(block(data))+"")


for j in range(0,20):
    if (j%2!=0 or j==0):
        write_html(index[j])


runhtml()
# Out:
# Block was added with
#  Timestamp=Genesis Time
#  lastHash=
#  Hash=f1r5t Ha5h
#  Data= 1st Block
#  epoch= 0
#
#
#
# Block was added with
#  Timestamp=1579902139415
#  lastHash= f1r5t Ha5h
#  Hash=143759e6d2e445e
#  Data= THIS IS BLOCK NO. 1
#  epoch= 99
#
#
#
# Block was added with
#  Timestamp=1579902139419
#  lastHash= 143759e6d2e445e
#  Hash=17ebf703ea57a80
#  Data= THIS IS BLOCK NO. 2
#  epoch= 599
#
#
#
# Block was added with
#  Timestamp=1579902139432
#  lastHash= 17ebf703ea57a80
#  Hash=1d1c7b25304525c
#  Data= THIS IS BLOCK NO. 3
#  epoch= 2175
#
#
#
# Block was added with
#  Timestamp=1579902139481
#  lastHash= 1d1c7b25304525c
#  Hash=1135cdf4f36e0b7
#  Data= THIS IS BLOCK NO. 4
#  epoch= 393
#
#
#
# Block was added with
#  Timestamp=1579902139491
#  lastHash= 1135cdf4f36e0b7
#  Hash=17851f155a4d89a
#  Data= THIS IS BLOCK NO. 5
#  epoch= 4138
#
#
#
# Block was added with
#  Timestamp=1579902139575
#  lastHash= 17851f155a4d89a
#  Hash=162ba8f78a65a52
#  Data= THIS IS BLOCK NO. 6
#  epoch= 943
#
#
#
# Block was added with
#  Timestamp=1579902139602
#  lastHash= 162ba8f78a65a52
#  Hash=16f38549e6dcca5
#  Data= THIS IS BLOCK NO. 7
#  epoch= 396
#
#
#
# Block was added with
#  Timestamp=1579902139615
#  lastHash= 16f38549e6dcca5
#  Hash=10ac303d5ce60db
#  Data= THIS IS BLOCK NO. 8
#  epoch= 2209
#
#
#
# Block was added with
#  Timestamp=1579902139667
#  lastHash= 10ac303d5ce60db
#  Hash=12828be34362a1a
#  Data= THIS IS BLOCK NO. 9
#  epoch= 156
#
#
#
# Block was added with
#  Timestamp=1579902139671
#  lastHash= 12828be34362a1a
#  Hash=18e6d7461843bcb
#  Data= THIS IS BLOCK NO. 10
#  epoch= 1744
#
#
#
# Block was added with
#  Timestamp=1579902139706
#  lastHash= 18e6d7461843bcb
#  Hash=12bee2ec2ec6149
#  Data= THIS IS BLOCK NO. 11
#  epoch= 875
#
#
#
# Block was added with
#  Timestamp=1579902139724
#  lastHash= 12bee2ec2ec6149
#  Hash=1890d5bc208b884
#  Data= THIS IS BLOCK NO. 12
#  epoch= 1662
#
#
#
# Block was added with
#  Timestamp=1579902139760
#  lastHash= 1890d5bc208b884
#  Hash=1b5a01f41805dd4
#  Data= THIS IS BLOCK NO. 13
#  epoch= 214
#
#
#
# Block was added with
#  Timestamp=1579902139765
#  lastHash= 1b5a01f41805dd4
#  Hash=118eae81ee7c2f1
#  Data= THIS IS BLOCK NO. 14
#  epoch= 141
#
#
#
# Block was added with
#  Timestamp=1579902139769
#  lastHash= 118eae81ee7c2f1
#  Hash=1a72434975e68da
#  Data= THIS IS BLOCK NO. 15
#  epoch= 1496
#
#
#
# Block was added with
#  Timestamp=1579902139803
#  lastHash= 1a72434975e68da
#  Hash=16f876e8426c36f
#  Data= THIS IS BLOCK NO. 16
#  epoch= 336
#
#
#
# Block was added with
#  Timestamp=1579902139814
#  lastHash= 16f876e8426c36f
#  Hash=1407117adaaf265
#  Data= THIS IS BLOCK NO. 17
#  epoch= 1269
#
#
#
# Block was added with
#  Timestamp=1579902139868
#  lastHash= 1407117adaaf265
#  Hash=101f774a4b78b9d
#  Data= THIS IS BLOCK NO. 18
#  epoch= 359
#
#
#
# Block was added with
#  Timestamp=1579902139881
#  lastHash= 101f774a4b78b9d
#  Hash=1f2945fb138c7e0
#  Data= THIS IS BLOCK NO. 19
#  epoch= 339
